# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd 
import sqlalchemy

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'api.cdn.dcg-search.com',
    'sec-ch-ua': '^\\^',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.55 Safari/537.36 Edg/96.0.1054.34',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'accept': '*/*',
    'origin': 'https://www.currys.co.uk',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.currys.co.uk/',
    'accept-language': 'en-GB,en;q=0.9,en-US;q=0.8,de;q=0.7',
}

params = (
    ('do', 'json'),
    ('m_results_per_page', '20'),
    ('page', '1'),
    ('q1', '550'),
    ('q2', '4278'),
    ('q3', '31971'),
    ('sort', 'relevance'),
    ('sp_cs', 'UTF-8'),
    ('x1', 'category_id'),
    ('x2', 'market_id'),
    ('x3', 'segment_id'),
)

response = requests.get('https://api.cdn.dcg-search.com/currys/navigation', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
result_json = response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
result_json.keys()
# Out:
# dict_keys(['general', 'banners', 'menus', 'breadcrumbs', 'pagination', 'facets', 'resultsets', 'resultcount', 'price_range'])

# %%
listing = result_json['resultsets']['default']['results']

# %%
len(listing)
# Out:
# 20

# %% [markdown]
# #### Step 6 - Find your Data

# %% [markdown]
# - Product Title
# - Brand
# - Price
# - Review Score
# - Review Count
# - Description

# %%
# product title
listing[0]['title']
# Out:
# 'PN7 XBOOM Go Portable Bluetooth Speaker - Black'

# %%
# brand
listing[0]['brand']
# Out:
# 'LG'

# %%
# price
listing[0]['price']
# Out:
# '84.5'

# %%
# review score
listing[0]['reevoo_score']
# Out:
# '9.1'

# %%
# review count
listing[0]['reevoo_count']
# Out:
# '245'

# %%
# description
listing[0]['short_description']
# Out:
# 'Water resistant, Up to 24 hours battery life, Bluetooth, Aux-in, Pair up to 100 speakers'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
# empty list
product_title = []
brand = []
price = []
review_score = []
review_count = []
description = []


for result in listing:
    
    # product title
    product_title.append(result['title'])
    
    # brand
    brand.append(result['brand'])
    
    # price
    price.append(result['price'])
    
    # review score
    review_score.append(result['reevoo_score'])
    
    # review count
    review_count.append(result['reevoo_count'])
    
    # description
    description.append(result['short_description'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
speakers_df = pd.DataFrame({'product_title': product_title, 'brand':brand, 'price_£':price,
                           'review_score': review_score, 'review_count':review_count, 'description': description})

speakers_df
# Out:
#                                         product_title      brand price_£  \
# 0     PN7 XBOOM Go Portable Bluetooth Speaker - Black         LG    84.5
# 1   XBOOM 360 RP4 Portable Bluetooth Speaker - Bur...         LG     299
# 2         Charge 5 Portable Bluetooth Speaker - Black        JBL     159
# 3   Charge 5 Portable Bluetooth Speaker - Black TM...        JBL     129
# 4         SRS-XB13 Portable Bluetooth Speaker - Black       SONY      35
# 5   One Wireless Multi-room Speaker with Amazon Al...      SONOS     184
# 6     PN5 XBOOM Go Portable Bluetooth Speaker - Black         LG    64.5
# 7   UX-D327B Wireless Traditional Hi-Fi System - B...        JVC   64.99
# 8          One SL Wireless Multi-room Speaker - Black      SONOS     169
# 9   One Wireless Multi-room Speaker with Amazon Al...      SONOS     184
# 10   RD-D80 Bluetooth All-in-One Hi-Fi System - Black        JVC   99.99
# 11       MX-D829PB Portable Bluetooth Speaker - Black        JVC     129
# 12  XS-D629BM 2.0 Bluetooth Bookshelf Speakers - W...        JVC   79.99
# 13  RD-D100 Bluetooth All-in-One Hi-Fi System - Black        JVC     129
# 14         One SL Wireless Multi-room Speaker - White      SONOS     169
# 15         Flare 2 Portable Bluetooth Speaker - Black  SOUNDCORE   37.99
# 16       MX-D719PB Portable Bluetooth Speaker - Black        JVC   99.99
# 17  UX-D529B Bluetooth Flat Panel Hi-Fi System - B...        JVC   69.99
# 18  CM4360 XBOOM Bluetooth Megasound Party Hi-Fi S...         LG   99.99
# 19    DT-1 Bluetooth Traditional Hi-Fi System - Black      DENON     209
#
#    review_score review_count  \
# 0           9.1          245
# 1             0
# 2           9.3           87
# 3           9.3           87
# 4           9.1           53
# 5             9          722
# 6           9.4          105
# 7           8.5          802
# 8           9.3          308
# 9             9          722
# 10            9          349
# 11          9.6          103
# 12            9          315
# 13            9          282
# 14          9.3          308
# 15          9.2           13
# 16          9.4          246
# 17          8.9           66
# 18          9.4           83
# 19            9           67
#
#                                           description
# 0   Water resistant, Up to 24 hours battery life, ...
# 1   360° Omnidirectional Sound for room-filling au...
# 2   Waterproof, Up to 20 hours battery life, Bluet...
# 3   Waterproof, Up to 20 hours battery life, Bluet...
# 4   Waterproof, Up to 16 hours battery life, Bluet...
# 5   Wirelessly connect to other Sonos speakers, Wi...
# 6   Water resistant, Up to 18 hours battery life, ...
# 7   CD player, DAB / FM radio, Bluetooth, USB / Au...
# 8   Wirelessly connect to other Sonos speakers, Wo...
# 9   Wirelessly connect to other Sonos speakers, Wi...
# 10  CD player, DAB+/DAB / FM radio, Bluetooth, Out...
# 11  Up to 26 hours battery life, Bluetooth, Aux-in...
# 12  Output power: 60 W, Bluetooth, USB / RCA, USB ...
# 13  CD player, DAB+/DAB / FM radio, Bluetooth, Out...
# 14  Wirelessly connect to other Sonos speakers, Wo...
# 15  Waterproof, Up to 12 hours battery life, Bluet...
# 16  Up to 12 hours battery life, Bluetooth, Aux-in...
# 17  CD player, DAB+/DAB / FM radio, Bluetooth, Out...
# 18  CD player, FM radio, Bluetooth, Output power: ...
# 19  CD player, FM/AM radio, Bluetooth, Output powe...

# %%
# store in excel
speakers_df.to_excel('speakers_single.xlsx', index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 20 pages to get 400 results)

# %%
# empty list
product_title = []
brand = []
price = []
review_score = []
review_count = []
description = []

headers = {
    'authority': 'api.cdn.dcg-search.com',
    'sec-ch-ua': '^\\^',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.55 Safari/537.36 Edg/96.0.1054.34',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'accept': '*/*',
    'origin': 'https://www.currys.co.uk',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.currys.co.uk/',
    'accept-language': 'en-GB,en;q=0.9,en-US;q=0.8,de;q=0.7',
}

for i in range(1,21):

    params = (
        ('do', 'json'),
        ('m_results_per_page', '20'),
        ('page', str(i)),
        ('q1', '550'),
        ('q2', '4278'),
        ('q3', '31971'),
        ('sort', 'relevance'),
        ('sp_cs', 'UTF-8'),
        ('x1', 'category_id'),
        ('x2', 'market_id'),
        ('x3', 'segment_id'),
    )

    response = requests.get('https://api.cdn.dcg-search.com/currys/navigation', headers=headers, params=params)

    result_json = response.json() 
    
    listing = result_json['resultsets']['default']['results']
    
    for result in listing:
    
        # product title
        try:
            product_title.append(result['title'])
        except:
            product_title.append('')

        # brand
        try:
            brand.append(result['brand'])
        except:
            brand.append('')

        # price
        try:
            price.append(float(result['price']))
        except:
            price.append('')

        # review score
        try:
            review_score.append(float(result['reevoo_score']))
        except:
            review_score.append('')

        # review count
        try:
            review_count.append(int(result['reevoo_count']))
        except:
            review_count.append('')

        # description
        try:
            description.append(result['short_description'])
        except:
            description('')
    
speakers_multiple_df = pd.DataFrame({'product_title': product_title, 'brand':brand, 'price_£':price,
                           'review_score': review_score, 'review_count':review_count, 'description': description})

speakers_multiple_df
# Out:
#                                          product_title     brand   price_£  \
# 0      PN7 XBOOM Go Portable Bluetooth Speaker - Black        LG     84.50
# 1    XBOOM 360 RP4 Portable Bluetooth Speaker - Bur...        LG    299.00
# 2          Charge 5 Portable Bluetooth Speaker - Black       JBL    159.00
# 3    Charge 5 Portable Bluetooth Speaker - Black TM...       JBL    129.00
# 4          SRS-XB13 Portable Bluetooth Speaker - Black      SONY     35.00
# ..                                                 ...       ...       ...
# 395  Amitabh Bachchan Bluetooth Jukebox - Limited E...  RICATECH  20000.00
# 396  I58058 LED Disco Ball Portable Bluetooth Speak...      ITEK     29.99
# 397      Pocket 2.0 Portable Bluetooth Speaker - Black      HAMA     20.99
# 398                        DCD-800NE CD Player - Black     DENON    399.00
# 399           Clip 4 Portable Bluetooth Speaker - Blue       JBL     49.99
#
#      review_score review_count  \
# 0             9.1          245
# 1             0.0
# 2             9.3           87
# 3             9.3           87
# 4             9.1           53
# ..            ...          ...
# 395           0.0
# 396           0.0
# 397           9.7            3
# 398           9.2           16
# 399           0.0
#
#                                            description
# 0    Water resistant, Up to 24 hours battery life, ...
# 1    360° Omnidirectional Sound for room-filling au...
# 2    Waterproof, Up to 20 hours battery life, Bluet...
# 3    Waterproof, Up to 20 hours battery life, Bluet...
# 4    Waterproof, Up to 16 hours battery life, Bluet...
# ..                                                 ...
# 395     CD player, Bluetooth, Output power: 800 W, RCA
# 396      Up to 3 hours battery life, Bluetooth, Aux-in
# 397  Waterproof, Up to 14 hours battery life, Bluet...
# 398  USB / Coaxial / Optical / RCA, Supports High-R...
# 399  Waterproof, Up to 10 hours battery life, Bluet...
#
# [400 rows x 6 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
speakers_multiple_df.to_excel('speakers_multiple.xlsx', index=False)

# %% [markdown]
# #### Step 11 - Store in PostgreSQL

# %%
# create sqlalchemy engine
engine = sqlalchemy.create_engine('postgres://postgres:12345@localhost:5432')
speakers_multiple_df.to_sql('e_commerce', engine, index=False)
