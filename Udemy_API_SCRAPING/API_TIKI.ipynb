# %%
import requests
import pandas as pd
import sqlalchemy

# %%
import requests

headers = {
    'authority': 'tiki.vn',
    'sec-ch-ua': '^\\^CocCoc^\\^;v=^\\^95^\\^, ^\\^Chromium^\\^;v=^\\^95^\\^, ^\\^;Not',
    'accept': 'application/json, text/plain, */*',
    'x-guest-token': 'XaUorvjFuKW9TSfqcidPm8h4QLgVywxB',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.84 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://tiki.vn/search?q=laptop&page=2',
    'accept-language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': '_trackity=22542aba-f0ee-fae2-be05-30f5ca7bd13d; TOKENS=^{^%^22access_token^%^22:^%^22XaUorvjFuKW9TSfqcidPm8h4QLgVywxB^%^22^%^2C^%^22expires_in^%^22:157680000^%^2C^%^22expires_at^%^22:1797238695226^%^2C^%^22guest_token^%^22:^%^22XaUorvjFuKW9TSfqcidPm8h4QLgVywxB^%^22^}; _gid=GA1.2.1633890692.1639558693; _gac_UA-15036050-1=1.1639558693.Cj0KCQiAweaNBhDEARIsAJ5hwbcKlsf6tMvMRCxf3p8_Y3omnWoOJJCD7yIBV44e0F_h6j6lvE0P4hsaAkHXEALw_wcB; amp_99d374=LC79gIFE8-_PHXpOn14jyX...1fmul0g8l.1fmul0gbm.2.7.9; _gcl_aw=GCL.1639558693.Cj0KCQiAweaNBhDEARIsAJ5hwbcKlsf6tMvMRCxf3p8_Y3omnWoOJJCD7yIBV44e0F_h6j6lvE0P4hsaAkHXEALw_wcB; _gcl_au=1.1.452829196.1639558693; tiki_client_id=831125281.1639558693; _ga=GA1.1.831125281.1639558693; __utm=source^%^3Dgoogle^%^7Cmedium^%^3Dcpc^%^7Ccampaign^%^3DSEA_NBR_GGL_TXT_SBR_ALL_VN_ALL_UNK_UNK_C.ALL_X.9805780973_Y.99446805025_Q.e_K.Tiki_W.DT_R.430254349622_T.aud-892837214299^%^253Akwd-10246492_L.HP_O.CIR; __utm=source^%^3Dgoogle^%^7Cmedium^%^3Dcpc^%^7Ccampaign^%^3DSEA_NBR_GGL_TXT_SBR_ALL_VN_ALL_UNK_UNK_C.ALL_X.9805780973_Y.99446805025_Q.e_K.Tiki_W.DT_R.430254349622_T.aud-892837214299^%^253Akwd-10246492_L.HP_O.CIR; __iid=749; __iid=749; __su=0; __su=0; __RC=20; __R=1; __uif=__uid^%^3A5238403584246807763^%^7C__ui^%^3A1^%^252C4^%^7C__create^%^3A1638403584; cto_bundle=1LGba19qeGVKYnB4cTJhR3hNODYyQktRd2lBMXFreWpOZWJScUFPM1RqdXZ6VUUxODVMV2dxQndnV29JMDU1ZmxNWVNBUVU1bDVwTVAxJTJCcTdlRXM5OWJmUklzbzduT2FLOGg3RnpJbjJuZk44dmg1VWlUbEdqRWtYbmNKTmlDNDVTa052V2xNd1l1TXpMenJLZ1BGcHM2S3pQdyUzRCUzRA; _hjSessionUser_522327=eyJpZCI6IjcxZTEyODNjLWJkZTQtNTc2Ny1hODRkLTEzYTZhNzljODE4YyIsImNyZWF0ZWQiOjE2Mzk1NTg2OTQxOTMsImV4aXN0aW5nIjpmYWxzZX0=; _hjFirstSeen=1; _hjSession_522327=eyJpZCI6IjY1NDIwOWM0LWQ4ZDEtNDM1OC05MTE3LTQ3ZjI2Yzc4OTY0MCIsImNyZWF0ZWQiOjE2Mzk1NTg2OTc0NDd9; _hjIncludedInSessionSample=0; _hjAbsoluteSessionInProgress=0; _gat=1; amp_99d374_tiki.vn=LC79gIFE8-_PHXpOn14jyX...1fmul0g8l.1fmulrd7c.8.f.n; _ga_GSD4ETCY1D=GS1.1.1639558694.1.1.1639559584.0',
}

params = (
    ('limit', '48'),
    ('include', 'advertisement'),
    ('aggregations', '2'),
    ('trackity_id', '22542aba-f0ee-fae2-be05-30f5ca7bd13d'),
    ('q', 'laptop'),
    ('page', '2'),
)

response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'data': [{'id': 72750441,
#    'sku': '1525769524578',
#    'name': 'Bàn Phím Cơ mini không dây Bluetooth 5.0 Ajazz AK33 White Chống ồn - hàng nhập khẩu',
#    'url_key': 'ban-phim-co-mini-khong-day-bluetooth-5-0-ajazz-ak33-whitechong-on-hang-nhap-khau-p72750441',
#    'url_path': 'ban-phim-co-mini-khong-day-bluetooth-5-0-ajazz-ak33-whitechong-on-hang-nhap-khau-p72750441.html?spid=72750444',
#    'type': 'simple',
#    'brand_name': 'Ajazz',
#    'short_description': '- Bàn Phím Cơ mini không dây Bluetooth 5.0 Ajazz AK33 Chống ồn Gọn gàng , đơn giản và tinh tế- Switch 82 Phím Chống ồn- Led trắng đơn sắc đơn giản sang trọng không màu mè- Chất liệu kim loại- Kết nối...',
#    'price': 930000,
#    'list_price': 930000,
#    'original_price': 930000,
#    'badges_new': [{'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'under_price',
#      'type': 'under_price_icon',
#      'code': 'is_best_price_guaranteed',
#      'icon': 'https://salt.tikicdn.com/ts/upload/51/ac/cc/528e80fe3f464f910174e2fdf8887b6f.png',
#      'icon_width': 124,
#      'icon_height': 18,
#      'text': ''},
#     {'placement': 'bottom_right',
#      'type': 'icon_badge',
#      'code': 'video_icon',
#      'icon': 'https://salt.tikicdn.com/ts/upload/d5/f3/6f/fdd40db52ff4afe497d0c2240dcfd25b.png',
#      'icon_width': 28,
#      'icon_height': 28},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'trusted_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/e0/41/da/bb0fc684a838eff5e264ce0534a148f0.png',
#      'icon_width': 58,
#      'icon_height': 18}],
#    'discount': 0,
#    'discount_rate': 0,
#    'rating_average': 5,
#    'review_count': 2,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/24/09/4a/97a5be480a7ed46e757be248279bfc98.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 3755,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'dropship'},
#    'stock_item': {'qty': 5,
#     'min_sale_qty': 1,
#     'max_sale_qty': 30,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 72750444,
#    'video_url': 'https://salt.tikicdn.com/ts/video/f2/26/2c/befac9eecc98dcfd9e3c4260ef12bf2f.mp4',
#    'quantity_sold': {'text': 'Đã bán 6', 'value': 6},
#    'shippable': True,
#    'advertisement': {'ad': [{'clickUrl': '//tka.tiki.vn/pixel/pixel?data=djAw
 'https://salt.tikicdn.com/ts/upload/9f/32/dd/8a8d39d4453399569dfb3e80fe01de75.png',
#      'icon_width': 56,
#      'icon_height': 16,
#      'text': '',
#      'text_color': '#00AB56'},
#     {'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'benefits',
#      'type': 'benefits_badge',
#      'code': 'installment',
#      'icon': 'https://salt.tikicdn.com/ts/upload/fc/d8/25/e61805952396b6ed4143194298112b0a.png',
#      'icon_width': 16,
#      'icon_height': 16,
#      'text': 'Trả góp'},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'official_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/b9/1f/4b/557eac9c67a4466ccebfa74cde854215.png',
#      'icon_width': 74,
#      'icon_height': 18}],
#    'discount': 3400000,
#    'discount_rate': 10,
#    'rating_average': 5,
#    'review_count': 377,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/media/catalog/producttmp/45/27/73/b9f17d26b5a4e9e6aa4bba27a2242d2d.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2493,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'tiki_delivery'},
#    'option_color': [{'spid': 88231358,
#      'display_name': 'Silver',
#      'is_default': 1,
#      'price': 30590000,
#      'list_price': 30590000,
#      'original_price': 30590000,
#      'thumbnail': 'https://salt.tikicdn.com/cache/200x200/media/catalog/producttmp/dc/2a/f2/83beb9f5dbecb164dab503ae8d80fca2.jpg',
#      'small_thumbnail': 'https://salt.tikicdn.com/cache/64x64/media/catalog/producttmp/dc/2a/f2/83beb9f5dbecb164dab503ae8d80fca2.jpg',
#      'url_path': 'apple-macbook-air-2020-m1-13-inchs-hang-chinh-hang-p124742926.html?spid=88231358'},
#     {'spid': 88231356,
#      'display_name': 'Space Gray',
#      'is_default': 0,
#      'price': 30590000,
#      'list_price': 30590000,
#      'original_price': 30590000,
#      'thumbnail': 'https://salt.tikicdn.com/cache/200x200/ts/product/93/a8/65/b24f2b91c90e1d772f2052486662ec7d.jpg',
#      'small_thumbnail': 'https://salt.tikicdn.com/cache/64x64/ts/product/93/a8/65/b24f2b91c90e1d772f2052486662ec7d.jpg',
#      'url_path': 'apple-macbook-air-2020-m1-13-inchs-hang-chinh-hang-p124742926.html?spid=88231356'},
#     {'spid': 88231360,
#      'display_name': 'Gold',
#      'is_default': 0,
#      'price': 30590000,
#      'list_price': 30590000,
#      'original_price': 30590000,
#      'thumbnail': 'https://salt.tikicdn.com/cache/200x200/media/catalog/producttmp/c6/c3/05/51f1ecd7f931e6d43f11c23ceee9e61e.jpg',
#      'small_thumbnail': 'https://salt.tikicdn.com/cache/64x64/media/catalog/producttmp/c6/c3/05/51f1ecd7f931e6d43f11c23ceee9e61e.jpg',
#      'url_path': 'apple-macbook-air-2020-m1-13-inchs-hang-chinh-hang-p124742926.html?spid=88231360'}],
#    'stock_item': {'qty': 4,
#     'min_sale_qty': 1,
#     'max_sale_qty': 5,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 88231358,
#    'installment_info': {'price': 5098333,
#     'month': '6',
#     'redirect_url': 'https://tiki.vn/installment?masterId=124742926&spid=88231358'},
#    'bundle_deal': True,
#    'quantity_sold': {'text': 'Đã bán 823', 'value': 823},
#    'shippable': True},
#   {'id': 125013938,
#    'sku': '5244909000196',
#    'name': 'Apple MacBook Pro M1 2020 - 13 Inchs (8GB / 16GB - 256GB / 512GB) - Hàng Chính Hãng',
#    'url_key': 'apple-macbook-pro-m1-2020-13-inchs-8gb-16gb-256gb-512gb-hang-chinh-hang-p125013938',
#    'url_path': 'apple-macbook-pro-m1-2020-13-inchs-8gb-16gb-256gb-512gb-hang-chinh-hang-p125013938.html?spid=88231365',
#    'type': 'configurable',
#    'brand_name': 'Apple',
#    'short_description': '\n\n\nNội dung tính năng\nMacbook Pro 13 inch thay đổi ngoạn mục nhờ chip Apple M1, với sức mạnh xử lý tăng thêm đến 2.8x, (1) tốc độ xử lý đồ họa nhanh hơn 5x1 cùng thời lượng pin lên đến 20 giờ – thời...',
#    'price': 35990000,
#    'list_price': 38990000,
#    'original_price': 38990000,
#    'badges': [{'code': 'tikinow', 'text': 'tikinow'},
#     {'price': 5998333,
#      'month': '6',
#      'code': 'installment',
#      'text': 'Trả góp 0%'}],
#    'badges_new': [{'placement': 'service',
#      'type': 'service_badge',
#      'code': 'tikinow',
#      'icon': 'https://salt.tikicdn.com/ts/upload/9f/32/dd/8a8d39d4453399569dfb3e80fe01de75.png',
#      'icon_width': 56,
#      'icon_height': 16,
#      'text': '',
#      'text_color': '#00AB56'},
#     {'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'benefits',
#      'type': 'benefits_badge',
#      'code': 'installment',
#      'icon': 'https://salt.tikicdn.com/ts/upload/fc/d8/25/e61805952396b6ed4143194298112b0a.png',
#      'icon_width': 16,
#      'icon_height': 16,
#      'text': 'Trả góp'},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'official_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/b9/1f/4b/557eac9c67a4466ccebfa74cde854215.png',
#      'icon_width': 74,
#      'icon_height': 18}],
#    'discount': 3000000,
#    'discount_rate': 8,
#    'rating_average': 4.8,
#    'review_count': 343,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/media/catalog/producttmp/cb/13/54/13b8b7f2e45532fd9b6c8f9d93a10c07.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2493,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'tiki_delivery'},
#    'option_color': [{'spid': 88231363,
#      'display_name': 'Space Gray',
#      'is_default': 0,
#      'price': 35990000,
#      'list_price': 35990000,
#      'original_price': 35990000,
#      'thumbnail': 'https://salt.tikicdn.com/cache/200x200/ts/product/a7/e8/d6/161ba750631c96606c91c4b2cf7c114d.jpg',
#      'small_thumbnail': 'https://salt.tikicdn.com/cache/64x64/ts/product/a7/e8/d6/161ba750631c96606c91c4b2cf7c114d.jpg',
#      'url_path': 'apple-macbook-pro-m1-2020-13-inchs-8gb-16gb-256gb-512gb-hang-chinh-hang-p125013938.html?spid=88231363'},
#     {'spid': 88213617,
#      'display_name': 'Silver',
#      'is_default': 0,
#      'price': 40290000,
#      'list_price': 40290000,
#      'original_price': 40290000,
#      'thumbnail': 'https://salt.tikicdn.com/cache/200x200/ts/product/90/c1/c8/09701fb2f358b4172654d14caf8fbe62.jpg',
#      'small_thumbnail': 'https://salt.tikicdn.com/cache/64x64/ts/product/90/c1/c8/09701fb2f358b4172654d14caf8fbe62.jpg',
#      'url_path': 'apple-macbook-pro-m1-2020-13-inchs-8gb-16gb-256gb-512gb-hang-chinh-hang-p125013938.html?spid=88213617'}],
#    'stock_item': {'qty': 13,
#     'min_sale_qty': 1,
#     'max_sale_qty': 5,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 88231365,
#    'installment_info': {'price': 5998333,
#     'month': '6',
#     'redirect_url': 'https://tiki.vn/installment?masterId=125013938&spid=88231365'},
#    'quantity_sold': {'text': 'Đã bán 853', 'value': 853},
#    'shippable': True},
#   {'id': 143022287,
#    'sku': '3226775600659',
#    'name': 'Laptop Asus ZenBook Flip S UX371EA-HL725WS (Core i7-1165G7/ 16GB LPDDR4x/ 1TB SSD/ 13.3 OLED 4K UHD Touch/ Win11) - Hàng Chính Hãng',
#    'url_key': 'laptop-asus-zenbook-flip-s-ux371ea-hl725ws-core-i7-1165g7-16gb-lpddr4x-1tb-ssd-13-3-oled-4k-uhd-touch-win11-hang-chinh-hang-p143022287',
#    'url_path': 'laptop-asus-zenbook-flip-s-ux371ea-hl725ws-core-i7-1165g7-16gb-lpddr4x-1tb-ssd-13-3-oled-4k-uhd-touch-win11-hang-chinh-hang-p143022287.html?spid=143022289',
#    'type': 'simple',
#    'brand_name': 'Asus',
#    'short_description': 'Thiết kế đẹp mắt, hiện đại\nLaptop Asus ZenBook Flip S UX371EA-HL725WS\xa0là 1 chiếc ultrabook có thiết kế nhẹ nhàng với lớp vỏ được phủ lớp sơn đen nhám và các cạnh vát kim cương màu đồng xung quanh...',
#    'price': 39759000,
#    'list_price': 41990000,
#    'original_price': 41990000,
#    'badges': [{'code': 'tikinow', 'text': 'tikinow'},
#     {'price': 6626500,
#      'month': '6',
#      'code': 'installment',
#      'text': 'Trả góp 0%'}],
#    'badges_new': [{'placement': 'service',
#      'type': 'service_badge',
#      'code': 'tikinow',
#      'icon': 'https://salt.tikicdn.com/ts/upload/9f/32/dd/8a8d39d4453399569dfb3e80fe01de75.png',
#      'icon_width': 56,
#      'icon_height': 16,
#      'text': '',
#      'text_color': '#00AB56'},
#     {'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'benefits',
#      'type': 'benefits_badge',
#      'code': 'installment',
#      'icon': 'https://salt.tikicdn.com/ts/upload/fc/d8/25/e61805952396b6ed4143194298112b0a.png',
#      'icon_width': 16,
#      'icon_height': 16,
#      'text': 'Trả góp'},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'official_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/b9/1f/4b/557eac9c67a4466ccebfa74cde854215.png',
#      'icon_width': 74,
#      'icon_height': 18}],
#    'discount': 2231000,
#    'discount_rate': 5,
#    'rating_average': 0,
#    'review_count': 0,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/a8/29/b7/cd4e550023a868ce7cedcd1ea0e91fcf.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'tiki_delivery'},
#    'stock_item': {'qty': 3,
#     'min_sale_qty': 1,
#     'max_sale_qty': 1,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 143022289,
#    'installment_info': {'price': 6626500,
#     'month': '6',
#     'redirect_url': 'https://tiki.vn/installment?masterId=143022287&spid=143022289'},
#    'shippable': True},
#   {'id': 116629798,
#    'sku': '5037884571283',
#    'name': 'Đế tản nhiệt laptop máy tính 3, 6 quạt có đèn LED cực đẹp, chạy êm, làm mát hiệu quả thích hợp cho nhiều loại laptop tặng kèm móc khóa 5TECH',
#    'url_key': 'de-tan-nhiet-laptop-may-tinh-3-6-quat-co-den-led-cuc-dep-chay-em-lam-mat-hieu-qua-thich-hop-cho-nhieu-loai-laptop-tang-kem-moc-khoa-5tech-p116629798',
#    'url_path': 'de-tan-nhiet-laptop-may-tinh-3-6-quat-co-den-led-cuc-dep-chay-em-lam-mat-hieu-qua-thich-hop-cho-nhieu-loai-laptop-tang-kem-moc-khoa-5tech-p116629798.html?spid=116629800',
#    'type': 'configurable',
#    'brand_name': 'OEM',
#    'short_description': 'Đế tản nhiệt laptop máy tính có đèn LED cực đẹp, chạy êm, làm mát hiệu quả thích hợp cho nhiều loại laptop tặng kèm móc khóa 5TECH\nLưu ý: Nên cắm trực tiếp tản nhiệt vào ổ điện qua củ sạc điện thoại...',
#    'price': 249000,
#    'list_price': 249000,
#    'original_price': 249000,
#    'badges': [{'code': 'tikinow', 'text': 'tikinow'}],
#    'badges_new': [{'placement': 'service',
#      'type': 'service_badge',
#      'code': 'tikinow',
#      'icon': 'https://salt.tikicdn.com/ts/upload/9f/32/dd/8a8d39d4453399569dfb3e80fe01de75.png',
#      'icon_width': 56,
#      'icon_height': 16,
#      'text': '',
#      'text_color': '#00AB56'},
#     {'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'trusted_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/e0/41/da/bb0fc684a838eff5e264ce0534a148f0.png',
#      'icon_width': 58,
#      'icon_height': 18}],
#    'discount': 0,
#    'discount_rate': 0,
#    'rating_average': 4.6,
#    'review_count': 19,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/ef/49/84/fd13b547344a11ef799c7fd39566175b.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 3715,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'tiki_delivery'},
#    'stock_item': {'qty': 7,
#     'min_sale_qty': 1,
#     'max_sale_qty': 20,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 116629800,
#    'quantity_sold': {'text': 'Đã bán 34', 'value': 34},
#    'shippable': True,
#    'advertisement': {'ad': [{'clickUrl': '//tka.tiki.vn/pixel/pixel?data=djAwMRv-5sE4Ynl57oSG0rH20BKykdUpHEfLV7PrRuPo9SiWtgJIfnXzO7d2ohkgoRqaVE4mebDdR6dTYCtzvSPrGW4SYOFUSMLCgJxBH1SBaEpMZ_NnCgZiO9SVMw0XcMx2yvwX8FkHlxVsCtznJvEr07kch7ouJx2-slzdTTiyK3yC9ZKElz48DUwGkaanSRoTLnAY5mGR_vzHzGW4MSta2EIOFog5E2NXR0dR0ljQOwO4qCW1J1erxTs7iYIr71ODn1Gzyu4b1MEgu1kh_xiJ9ZaXItnWHbeDH2KdVUB5hY7EWKgKdVCwnQrUrGx1adbRBebfA5LG7p-T6VRmaks_Ojq3wMMBTPSaSuvYNMfTN2yzDuFDvSrRJ8hNahf0k4aQ5Ll3YOI0nRz61Qdg6g2PGSRAuxw1frjYOrQrrdo8vEqsEOXCL9sDEpxe0XdD9CBR_cQNXZsVoKywaBc4vUwa4DXWbZZvHmarkuRLfC9fWEjYfYtTNj3Gf-tmNR7gi2d5ZEliRh4lci0svaaQVmxV-YL8PbLQUdxdxFYdZP5I4RFFbEHBBqVSliMEpJyd68zHL88FQ5JwppTEfLaaL2hUSzecsRqJxp6oUTRFof8ELnJHxrIELrBEVr6ujJ5Rt3tldfodLdh7Zfn7ToTrBSd71raHTEHnZzv11RihlpBx1ih1uNRkhXH_EheOAz3WhJ8xEu7GCnFFlItCXu4-PczJ8zBcGvN7So7zMtsGsklpfkVumc8aTHaFlhOEjts-fF23FjaMURiYvnix86FuHhZzRbR7wEXE-zBkAi-7duqKh_d9vccw8G4PIHOTSoYBBZGF53_tYv4S2DlmXK3ZyF4RZ8_QvOOeS5wjgLuiDwKvmnCuWJZnJUJXoVaivdxf9MjVb0oLbO9SgWIBq
I6PMeDgagi-RyV-r9cQQ8e6-yt-n_k0qtEjCJHGIZO4C-fY2kdX79pbNB-bpwPMXBIt-DjLwucgBZXZZoglulneNUHHCCLu1tDEb7nfXkRIH_DdpUgx5GeOayrVfYtPGWGKMRCYYDCZK8-7H4v7ni0gWZkMC9uGtnTxGu-oxhTM9pzWmTYFohZ2PnC_MAy7dlaQga67mOMH3-Scf-ULIIB_G1DCfE7LXlxSViIpt8i9kqf7-trPj0fZufkG1vnNnafI5mWUkkLkXOljJ7D_fnz_lG8dKA8wknUbQ7yAOIAvksU8T7VNfcHpIGI7Az985aA1sPTUA5YVuMLp7rXkqu1WXf2HTgUXdMbUlgr1_w-9jvlaDSVO_UuOmhkelx7ulMVWt180-O-Y2uSkGWnKGFx0Opzo8jXezpGpWsQ-pqWHbuHS-QgLYOlFttOCZagLZkLMF4ipl4dhtDEXaR0aWmqgcH0zOIZULlcqvafTMBbpRRpOIOKnNF-8xRBez3ZVQ&VIEW&reqid=IsfRPXb38E&pos=53',
#       'properties': {'product_id': '116629800'},
#       'type': 'ProductAdvertType',
#       'seller_id': 16224}]}},
#   {'id': 108591561,
#    'sku': '7704951705268',
#    'name': 'Laptop HP 340s G7 224L1PA i3 1005G1 | 4GB RAM | 512GB SSD | 14" FHD | Win 10 | Xám - Hàng Chính Hãng',
#    'url_key': 'laptop-hp-340s-g7-224l1pa-i3-1005g1-4gb-ram-512gb-ssd-14-fhd-win-10-xam-hang-chinh-hang-p108591561',
#    'url_path': 'laptop-hp-340s-g7-224l1pa-i3-1005g1-4gb-ram-512gb-ssd-14-fhd-win-10-xam-hang-chinh-hang-p108591561.html?spid=108591562',
#    'type': 'simple',
#    'brand_name': 'HP',
#    'short_description': '\n \n \n  \n   Thông số kỹ thuật:\n   RAM: 4GB(1 x 4GB) DDR4 2666Mhz (2 khe)\n   Ổ cứng: 512GB PCIe NVMe SSD\n   Màn hình: 14.0 inch FHD (1920 x 1080), IPS, anti-glare, 250 nits, 45% NTSC\n   Pin: 3-cell, 41...',
#    'price': 13890000,
#    'list_price': 13890000,
#    'original_price': 13890000,
#    'badges_new': [{'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'official_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/b9/1f/4b/557eac9c67a4466ccebfa74cde854215.png',
#      'icon_width': 74,
#      'icon_height': 18}],
#    'discount': 0,
#    'discount_rate': 0,
#    'rating_average': 0,
#    'review_count': 0,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/02/ac/05/f90004f9c7de859dfbaa309eb370b6b2.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'dropship'},
#    'stock_item': {'qty': 2,
#     'min_sale_qty': 1,
#     'max_sale_qty': 30,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 108591562,
#    'shippable': True},
#   {'id': 135093811,
#    'sku': '8466124629038',
#    'name': 'Laptop Dell Inspiron 15 3511 P112F001ABL (Đen) - Hàng chính hãng',
#    'url_key': 'laptop-dell-inspiron-15-3511-p112f001abl-den-hang-chinh-hang-p135093811',
#    'url_path': 'laptop-dell-inspiron-15-3511-p112f001abl-den-hang-chinh-hang-p135093811.html?spid=135093812',
#    'type': 'simple',
#    'brand_name': 'Dell',
#    'short_description': 'Laptop Dell Inspiron 15 3511 P112F001ABL với thiết kế thanh lịch, mạnh mẽ và mang trong mình một hiệu năng ổn định đủ giải quyết tốt các tác vụ văn phòng cơ bản đến nghe nhạc, xem phim giải trí hàng...',
#    'price': 15190000,
#    'list_price': 15190000,
#    'original_price': 15190000,
#    'discount': 0,
#    'discount_rate': 0,
#    'rating_average': 0,
#    'review_count': 0,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/b4/45/34/30140173b6c8870661901c1984b51dad.png',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'dropship'},
#    'stock_item': {'qty': 3,
#     'min_sale_qty': 1,
#     'max_sale_qty': 30,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 135093812,
#    'shippable': True},
#   {'id': 142795843,
#    'sku': '5497778605129',
#    'name': 'Laptop Dell Vostro 5415 V4R55500U015W (AMD R5-5500U/ 8GB/ 512GB SSD/ 14 FHD/ Win10 + Office) - Hàng Chính Hãng',
#    'url_key': 'laptop-dell-vostro-5415-v4r55500u015w-amd-r5-5500u-8gb-512gb-ssd-14-fhd-win10-office-hang-chinh-hang-p142795843',
#    'url_path': 'laptop-dell-vostro-5415-v4r55500u015w-amd-r5-5500u-8gb-512gb-ssd-14-fhd-win10-office-hang-chinh-hang-p142795843.html?spid=142795844',
#    'type': 'simple',
#    'brand_name': 'Dell',
#    'short_description': '\nHiệu năng mạnh mẽ, card đồ hoạ chất lượng\nLaptop Dell Vostro 5415 V4R55500U015W giúp xử lý mượt mà các vấn đề từ cơ bản đến nâng cao nhờ con chip AMD Ryzen 5. Các tác vụ phục vụ công việc cho bạn...',
#    'price': 19239000,
#    'list_price': 21990000,
#    'original_price': 21990000,
#    'badges': [{'code': 'tikinow', 'text': 'tikinow'},
#     {'price': 3206500,
#      'month': '6',
#      'code': 'installment',
#      'text': 'Trả góp 0%'}],
#    'badges_new': [{'placement': 'service',
#      'type': 'service_badge',
#      'code': 'tikinow',
#      'icon': 'https://salt.tikicdn.com/ts/upload/9f/32/dd/8a8d39d4453399569dfb3e80fe01de75.png',
#      'icon_width': 56,
#      'icon_height': 16,
#      'text': '',
#      'text_color': '#00AB56'},
#     {'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'under_price',
#      'type': 'under_price_icon',
#      'code': 'is_best_price_guaranteed',
#      'icon': 'https://salt.tikicdn.com/ts/upload/51/ac/cc/528e80fe3f464f910174e2fdf8887b6f.png',
#      'icon_width': 124,
#      'icon_height': 18,
#      'text': ''},
#     {'placement': 'benefits',
#      'type': 'benefits_badge',
#      'code': 'installment',
#      'icon': 'https://salt.tikicdn.com/ts/upload/fc/d8/25/e61805952396b6ed4143194298112b0a.png',
#      'icon_width': 16,
#      'icon_height': 16,
#      'text': 'Trả góp'},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'official_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/b9/1f/4b/557eac9c67a4466ccebfa74cde854215.png',
#      'icon_width': 74,
#      'icon_height': 18}],
#    'discount': 2751000,
#    'discount_rate': 13,
#    'rating_average': 3.8,
#    'review_count': 4,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/c3/0d/51/f058ae105d77a0488ac84d9e2cce5189.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'tiki_delivery'},
#    'stock_item': {'qty': 3,
#     'min_sale_qty': 1,
#     'max_sale_qty': 1,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 142795844,
#    'installment_info': {'price': 3206500,
#     'month': '6',
#     'redirect_url': 'https://tiki.vn/installment?masterId=142795843&spid=142795844'},
#    'quantity_sold': {'text': 'Đã bán 7', 'value': 7},
#    'shippable': True},
#   {'id': 120782190,
#    'sku': '9168518423896',
#    'name': 'Giá đỡ / Đế đỡ tản nhiệt dành cho laptop, macbook, máy tính bảng gấp gọn tiện dụng + tặng kèm túi đựng, ( Giao màu ngẫu nhiên )- Hàng chính hãng',
#    'url_key': 'gia-do-de-do-tan-nhiet-danh-cho-laptop-macbook-may-tinh-bang-gap-gon-tien-dung-tang-kem-tui-dung-giao-mau-ngau-nhien-hang-chinh-hang-p120782190',
#    'url_path': 'gia-do-de-do-tan-nhiet-danh-cho-laptop-macbook-may-tinh-bang-gap-gon-tien-dung-tang-kem-tui-dung-giao-mau-ngau-nhien-hang-chinh-hang-p120782190.html?spid=120782191',
#    'type': 'simple',
#    'brand_name': 'MAWA',
#    'short_description': 'Giá đỡ / Đế đỡ tản nhiệt dành cho laptop, macbook, máy tính bảng gấp gọn tiện dụng ( Giao màu ngẫu nhiên )- Hàng chính hãng\nTHÔNG TIN SẢN PHẨM\n- Màu sắc : Shop giao màu ngẫu nhiên ( Trắng bạc ,Hồng,...',
#    'price': 170000,
#    'list_price': 199000,
#    'original_price': 199000,
#    'badges': [{'code': 'tikinow', 'text': 'tikinow'}],
#    'badges_new': [{'placement': 'service',
#      'type': 'service_badge',
#      'code': 'tikinow',
#      'icon': 'https://salt.tikicdn.com/ts/upload/9f/32/dd/8a8d39d4453399569dfb3e80fe01de75.png',
#      'icon_width': 56,
#      'icon_height': 16,
#      'text': '',
#      'text_color': '#00AB56'},
#     {'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'under_price',
#      'type': 'under_price_icon',
#      'code': 'is_best_price_guaranteed',
#      'icon': 'https://salt.tikicdn.com/ts/upload/51/ac/cc/528e80fe3f464f910174e2fdf8887b6f.png',
#      'icon_width': 124,
#      'icon_height': 18,
#      'text': ''},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'trusted_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/e0/41/da/bb0fc684a838eff5e264ce0534a148f0.png',
#      'icon_width': 58,
#      'icon_height': 18}],
#    'discount': 29000,
#    'discount_rate': 15,
#    'rating_average': 5,
#    'review_count': 8,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/2b/45/0a/53d2b680bc1193aa946f2c310402567a.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 3715,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'tiki_delivery'},
#    'stock_item': {'qty': 18,
#     'min_sale_qty': 1,
#     'max_sale_qty': 20,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 120782191,
#    'quantity_sold': {'text': 'Đã bán 41', 'value': 41},
#    'shippable': True,
#    'advertisement': {'ad': [{'clickUrl': '//tka.tiki.vn/pixel/pixel?data=djAwMSp958wLwARpO1hBDw8zyA8jdPPk5kdcMFg-AIKvUxQdZfCIk-1iBrReqUFPkOtuYO5kUBtQl8g7xfL6X-5N6FmbDUeQGRjlGzS-fjul_3Zvrl6H9Yw1rzViejUuMq7rmUeEv2XuPhv7FYM5BoJbjxDKogQsgJcVuwjbGDlkkFzyrCKiIC0OZu9XNUzfB_rEsyjB5YMeWwfxAMI9SrsoL_E5oqxQ0-ByWpIb-MC-cW_lKbqgCO60KF0ZFCD1ua3miVumgUyk45iiv7qR_gFIcmOH5kgf4Qf_gkXOQgAQoANys6DPQCQ3XYItVmR_zMQWP0KW1nqIY6M_0fGVHtc9CNCGh3J_gYuMKU8YRDhHCfpnPbZ_cUNd_OCJOcXt7KBZ47KzuW4zvYiAkV_HQvp4ahQ6kc0MP6iA0BvE9yyEB56xyPSwjl3S6XPFZEHbOvsIOm_j62s2dxPyj9nALl-K-75PZgNXq6hngcuNw27YpYWLaJdgLq0VDPr_KWhHdWYM6GjinxVLIE7bP3ISkfcOofEatbTnlUaVvSinz8V7Klcv7Hnz3a1Wwg-Iny5dVAMSnpQXQcZyKBla-a4oCCRq3AdQxa8QXttJdTQDwyf

#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'freegift_items': [{'id': 101628913,
#      'masterId': 101628912,
#      'name': 'Balo chống sốc, chống va đập cho laptop từ 13-17 inch',
#      'thumbnail': 'https://salt.tikicdn.com/cache/w50/ts/product/42/3a/01/1d378c72b5147f21151869d3f7fa0b50.jpg'}],
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'dropship'},
#    'stock_item': {'qty': 30,
#     'min_sale_qty': 1,
#     'max_sale_qty': 30,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 137006840,
#    'shippable': True},
#   {'id': 127380504,
#    'sku': '4365506440169',
#    'name': "Laptop Dell Vostro 3400 (70253899) (i3-1115G4 | 8GB | 256GB | Intel UHD Graphics | 14' FHD | Win 10 | Office) -Hàng Chính Hãng",
#    'url_key': 'laptop-dell-vostro-3400-70253899-i3-1115g4-8gb-256gb-intel-uhd-graphics-14-fhd-win-10-office-hang-chinh-hang-p127380504',
#    'url_path': 'laptop-dell-vostro-3400-70253899-i3-1115g4-8gb-256gb-intel-uhd-graphics-14-fhd-win-10-office-hang-chinh-hang-p127380504.html?spid=127380505',
#    'type': 'simple',
#    'brand_name': 'Dell',
#    'short_description': 'Gọn gàng, tinh tế trên từng đường nét máyĐược chế tác từ lớp vỏ nhựa cứng cáp cùng những đường nét bo tròn tinh tế, Dell Vostro luôn gây ấn tượng với người dùng với thần thái kiêu sa, sang chảnh, nổi...',
#    'price': 14190000,
#    'list_price': 15990000,
#    'original_price': 15990000,
#    'badges_new': [{'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24}],
#    'discount': 1800000,
#    'discount_rate': 11,
#    'rating_average': 5,
#    'review_count': 3,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/2e/d0/ac/d84c8fab23f4a221638c5895b157991c.png',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'dropship'},
#    'stock_item': {'qty': 5,
#     'min_sale_qty': 1,
#     'max_sale_qty': 1,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 127380505,
#    'quantity_sold': {'text': 'Đã bán 19', 'value': 19},
#    'shippable': True},
#   {'id': 136959272,
#    'sku': '3892425863187',
#    'name': 'Laptop Dell XPS 13 9310 70262931 (Core i5-1135G7/8GB/256GB/Intel Iris Xe/13.4-inch FHD/Cảm ứng/Win 10/Bạc) - Hàng chính hãng',
#    'url_key': 'laptop-dell-xps-13-9310-70262931-core-i5-1135g7-8gb-256gb-intel-iris-xe-13-4-inch-fhd-cam-ung-win-10-bac-hang-chinh-hang-p136959272',
#    'url_path': 'laptop-dell-xps-13-9310-70262931-core-i5-1135g7-8gb-256gb-intel-iris-xe-13-4-inch-fhd-cam-ung-win-10-bac-hang-chinh-hang-p136959272.html?spid=136959412',
#    'type': 'simple',
#    'brand_name': 'Dell',
#    'short_description': 'Dell XPS 13 9310 2in1 70262931\xa0được thiết kế nhỏ gọn có thể giúp bạn mang\xa0 đi mọi nơi, phong cách phù hợp với nhiều đối tượng.\xa0\nDell XPS 13 9310 2in1 70262931\xa0được trang bị bộ xử lý\xa0Intel Core...',
#    'price': 41990000,
#    'list_price': 41990000,
#    'original_price': 41990000,
#    'badges_new': [{'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'under_price',
#      'type': 'under_price_icon',
#      'code': 'is_best_price_guaranteed',
#      'icon': 'https://salt.tikicdn.com/ts/upload/51/ac/cc/528e80fe3f464f910174e2fdf8887b6f.png',
#      'icon_width': 124,
#      'icon_height': 18,
#      'text': ''},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'official_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/b9/1f/4b/557eac9c67a4466ccebfa74cde854215.png',
#      'icon_width': 74,
#      'icon_height': 18}],
#    'discount': 0,
#    'discount_rate': 0,
#    'rating_average': 0,
#    'review_count': 0,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/0e/2f/be/35b6c2cfed7ad724dc93ca003ab63fec.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'dropship'},
#    'stock_item': {'qty': 1,
#     'min_sale_qty': 1,
#     'max_sale_qty': 30,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 136959412,
#    'quantity_sold': {'text': 'Đã bán 1', 'value': 1},
#    'shippable': True},
#   {'id': 137014231,
#    'sku': '1181475236961',
#    'name': 'Laptop HP Pavilion 15-eg0505TU (46M02PA) ( i5-1135G7/8GB RAM/512GB SSD/15.6 FHD/Win11/Vàng) Hàng Chính Hãng',
#    'url_key': 'laptop-hp-pavilion-15-eg0505tu-46m02pa-i5-1135g7-8gb-ram-512gb-ssd-15-6-fhd-win11-vang-hang-chinh-hang-p137014231',
#    'url_path': 'laptop-hp-pavilion-15-eg0505tu-46m02pa-i5-1135g7-8gb-ram-512gb-ssd-15-6-fhd-win11-vang-hang-chinh-hang-p137014231.html?spid=137014232',
#    'type': 'simple',
#    'brand_name': 'HP',
#    'short_description': '\nCPU: Intel Core i5-1135G7 (upto 4.20GHz, 8MB)\n\xa0\n\nRAM: 8GB(2 x 4GB) DDR4 3200MHz (2 Khe)\n\xa0\n\nỔ cứng: 512GB PCIe NVMe M.2 SSD\n\xa0\n\nVGA: Intel Iris Xe Graphics\n\xa0\n\nMàn hình: 15.6 inch FHD (1920 x 1080),...',
#    'price': 20990000,
#    'list_price': 20990000,
#    'original_price': 20990000,
#    'badges_new': [{'placement': 'bottom',
#      'type': 'icon_badge',
#      'code': 'freeship_tikifast',
#      'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#      'icon_width': 136,
#      'icon_height': 24},
#     {'placement': 'under_price',
#      'type': 'under_price_icon',
#      'code': 'is_best_price_guaranteed',
#      'icon': 'https://salt.tikicdn.com/ts/upload/51/ac/cc/528e80fe3f464f910174e2fdf8887b6f.png',
#      'icon_width': 124,
#      'icon_height': 18,
#      'text': ''},
#     {'placement': 'top',
#      'type': 'icon_badge',
#      'code': 'official_store',
#      'icon': 'https://salt.tikicdn.com/ts/upload/b9/1f/4b/557eac9c67a4466ccebfa74cde854215.png',
#      'icon_width': 74,
#      'icon_height': 18}],
#    'discount': 0,
#    'discount_rate': 0,
#    'rating_average': 0,
#    'review_count': 0,
#    'order_count': 0,
#    'favourite_count': 0,
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/70/75/57/0c677150afeb01bf614a30abb2c5280c.jpg',
#    'thumbnail_width': 280,
#    'thumbnail_height': 280,
#    'freegift_items': [{'id': 101628913,
#      'masterId': 101628912,
#      'name': 'Balo chống sốc, chống va đập cho laptop từ 13-17 inch',
#      'thumbnail': 'https://salt.tikicdn.com/cache/w50/ts/product/42/3a/01/1d378c72b5147f21151869d3f7fa0b50.jpg'}],
#    'has_ebook': False,
#    'inventory_status': 'available',
#    'productset_id': 2635,
#    'is_flower': False,
#    'is_gift_card': False,
#    'inventory': {'fulfillment_type': 'dropship'},
#    'stock_item': {'qty': 246,
#     'min_sale_qty': 1,
#     'max_sale_qty': 30,
#     'preorder_date': False},
#    'salable_type': '',
#    'seller_product_id': 137014232,
#    'shippable': True,
#    'advertisement': {'ad': [{'clickUrl': '//tka.tiki.vn/pixel/pixel?data=djAw
#    'url_key': 'laptop-hp-envy-13-ba1535tu-4u6m4pa-core-i7-1165g7-8gb-ram-512gb-ssd-13-3-fhd-win10-hang-chinh-hang-p135268246',
# ...
#     {'display_value': 'Asus',
#      'count': 15,
#      'query_value': '17826',
#      'url_key': 'thuong-hieu/asus.html'},
#     {'display_value': 'LG',
#      'count': 11,
#      'query_value': '18851',
#      'url_key': 'thuong-hieu/lg.html'},
#     {'display_value': 'MSI',
#      'count': 5,
#      'query_value': '49067',
#      'url_key': 'thuong-hieu/msi.html'},
#     {'display_value': 'Microsoft',
#      'count': 2,
#      'query_value': '19246',
#      'url_key': 'thuong-hieu/microsoft.html'},
#     {'display_value': 'HI PC',
#      'count': 1,
#      'query_value': '4968143',
#      'url_key': 'thuong-hieu/hi-pc.html'},
#     {'display_value': 'Huawei',
#      'count': 1,
#      'query_value': '19788',
#      'url_key': 'thuong-hieu/huawei.html'},
#     {'display_value': 'Surface',
#      'count': 1,
#      'query_value': '111973',
#      'url_key': 'thuong-hieu/surface.html'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_card',
#    'display_name': 'VGA Card',
#    'values': [{'display_value': 'Intel Iris',
#      'count': 18,
#      'query_value': '63873'},
#     {'display_value': 'Intel UHD Graphic',
#      'count': 12,
#      'query_value': '204757'},
#     {'display_value': 'NVIDIA Geforce', 'count': 5, 'query_value': '63872'},
#     {'display_value': 'Intel HD Graphic', 'count': 4, 'query_value': '63874'},
#     {'display_value': 'NVIDIA Geforce GTX',
#      'count': 2,
#      'query_value': '63878'},
#     {'display_value': 'AMD Radeon R5', 'count': 1, 'query_value': '63871'},
#     {'display_value': 'Intel UHD Graphics 620',
#      'count': 1,
#      'query_value': '155193'},
#     {'display_value': 'Intel® UHD Graphics 620',
#      'count': 1,
#      'query_value': '155165'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_cpu',
#    'display_name': 'CPU',
#    'values': [{'display_value': 'Intel Core i5',
#      'count': 29,
#      'query_value': '63849'},
#     {'display_value': 'Intel Core i3', 'count': 15, 'query_value': '63850'},
#     {'display_value': 'Intel Core i7', 'count': 15, 'query_value': '63848'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_hard_disk_type',
#    'display_name': 'Loại ổ cứng',
#    'values': [{'display_value': 'SSD', 'count': 61, 'query_value': '63860'},
#     {'display_value': 'DDR4', 'count': 9, 'query_value': '154927'},
#     {'display_value': 'SSD + HDD', 'count': 2, 'query_value': '160901'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_memory',
#    'display_name': 'RAM',
#    'values': [{'display_value': '8GB', 'count': 49, 'query_value': '63858'},
#     {'display_value': '4GB', 'count': 17, 'query_value': '63857'},
#     {'display_value': '16GB', 'count': 2, 'query_value': '63855'},
#     {'display_value': '32GB', 'count': 1, 'query_value': '65025'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_screen_size',
#    'display_name': 'Kích thước màn hình',
#    'values': [{'display_value': '15.6 inch',
#      'count': 50,
#      'query_value': '63882'},
#     {'display_value': '14 inch', 'count': 41, 'query_value': '63883'},
#     {'display_value': '13.3 inch', 'count': 16, 'query_value': '154855'},
#     {'display_value': '12.3 inch', 'count': 4, 'query_value': '166933'},
#     {'display_value': '14.1 inch', 'count': 1, 'query_value': '160903'},
#     {'display_value': '15 inch', 'count': 1, 'query_value': '160149'},
#     {'display_value': '17.3 inch', 'count': 1, 'query_value': '155421'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_series',
#    'display_name': 'Series',
#    'values': [{'display_value': 'Dell Vostro',
#      'count': 11,
#      'query_value': '63815'},
#     {'display_value': 'Dell Inspiron', 'count': 9, 'query_value': '63818'},
#     {'display_value': 'Dell Latitude', 'count': 3, 'query_value': '63817'},
#     {'display_value': 'HP Probook', 'count': 3, 'query_value': '63827'},
#     {'display_value': 'Lenovo Thinkpad', 'count': 3, 'query_value': '63832'},
#     {'display_value': 'Surface Pro 2018', 'count': 3, 'query_value': '254095'},
#     {'display_value': 'Lenovo Ideapad', 'count': 2, 'query_value': '63830'},
#     {'display_value': 'Acer Aspire A', 'count': 1, 'query_value': '154921'},
#     {'display_value': 'Acer Nitro 5', 'count': 1, 'query_value': '160623'},
#     {'display_value': 'Asus P Series', 'count': 1, 'query_value': '63812'},
#     {'display_value': 'Dell Alienware', 'count': 1, 'query_value': '158001'},
#     {'display_value': 'HP 14/15', 'count': 1, 'query_value': '63822'},
#     {'display_value': 'HP Pavilion', 'count': 1, 'query_value': '63828'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_storage',
#    'display_name': 'Dung lượng lưu trữ',
#    'values': [{'display_value': '512GB', 'count': 35, 'query_value': '158537'},
#     {'display_value': '256GB', 'count': 33, 'query_value': '156953'},
#     {'display_value': '128GB', 'count': 2, 'query_value': '156957'},
#     {'display_value': '1TB', 'count': 2, 'query_value': '63865'},
#     {'display_value': '240 GB - 256 GB', 'count': 2, 'query_value': '63868'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_system',
#    'display_name': 'Hệ điều hành',
#    'values': [{'display_value': 'Windows bản quyền',
#      'count': 78,
#      'query_value': '63890'},
#     {'display_value': 'Free Dos', 'count': 10, 'query_value': '63889'},
#     {'display_value': 'Mac OS X', 'count': 2, 'query_value': '63891'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'filter_laptop_touch',
#    'display_name': 'Cảm ứng',
#    'values': [{'display_value': 'Có', 'count': 9, 'query_value': '63887'},
#     {'display_value': 'Không', 'count': 54, 'query_value': '63888'}],
#    'collapsed': 5,
#    'multi_select': False},
#   {'query_name': 'option_color',
#    'display_name': 'Màu sắc',
#    'values': [{'display_value': 'Đen', 'count': 47265, 'query_value': 'Đen'},
#     {'display_value': 'Xám', 'count': 29575, 'query_value': 'Xám'},
#     {'display_value': 'Xanh', 'count': 18680, 'query_value': 'Xanh'},
#     {'display_value': 'Hồng', 'count': 16155, 'query_value': 'Hồng'},
#     {'display_value': 'Xanh dương',
#      'count': 12264,
#      'query_value': 'Xanh dương'},
#     {'display_value': 'Bạc', 'count': 9714, 'query_value': 'Bạc'},
#     {'display_value': 'Nâu', 'count': 7738, 'query_value': 'Nâu'},
#     {'display_value': 'Xanh lá', 'count': 7643, 'query_value': 'Xanh lá'},
#     {'display_value': 'Đỏ', 'count': 4790, 'query_value': 'Đỏ'},
#     {'display_value': 'Tím', 'count': 3823, 'query_value': 'Tím'},
#     {'display_value': 'Vàng', 'count': 3600, 'query_value': 'Vàng'},
#     {'display_value': 'Trắng', 'count': 3545, 'query_value': 'Trắng'},
#     {'display_value': 'Kem', 'count': 2134, 'query_value': 'Kem'},
#     {'display_value': 'Cam', 'count': 1253, 'query_value': 'Cam'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'seller',
#    'display_name': 'Nhà cung cấp',
#    'values': [{'display_value': 'fangleyuan',
#      'count': 33006,
#      'logo': 'https://salt.tikicdn.com/ts/seller/3c/fd/f8/a307a9ba3221fe27a061efd9d34ce5fe.jpg',
#      'query_value': 216403,
#      'seller_address': ''},
#     {'display_value': 'feiyinting',
#      'count': 30886,
#      'logo': 'https://salt.tikicdn.com/ts/seller/3c/fd/f8/e2b519dd14970a391f2d904e278ccf23.jpg',
#      'query_value': 219449,
#      'seller_address': ''},
#     {'display_value': 'fangcaoxiang',
#      'count': 28523,
#      'logo': 'https://salt.tikicdn.com/ts/seller/3c/fd/f8/ab09be3f11eda8c34da466090df0a81c.jpg',
#      'query_value': 219464,
#      'seller_address': ''},
#     {'display_value': 'Khang Minh Computer',
#      'count': 4158,
#      'logo': 'https://salt.tikicdn.com/ts/seller/74/f5/8d/074a2c6d9af7052d1c9d002e4ddbe9b6.jpg',
#      'query_value': 154264,
#      'seller_address': '28 Bà Triệu, Phường Hàng Bài, Quận Hoàn Kiếm, Hà Nội'},
#     {'display_value': 'Đạt Khang Network',
#      'count': 4040,
#      'logo': 'https://salt.tikicdn.com/ts/seller/ec/5c/73/60e5950c1012bd895f027c092185e03c.jpg',
#      'query_value': 170124,
#      'seller_address': 'Ngõ 32 Bà Triệu (Cạnh bộ ngoại giao), Phường Hàng Bài, Quận Hoàn Kiếm, Hà Nội'},
#     {'display_value': 'KOW Computer',
#      'count': 3526,
#      'logo': 'https://salt.tikicdn.com/ts/seller/4b/54/1a/f385a79a716cb3505f152e7af8c769aa.png',
#      'query_value': 138415,
#      'seller_address': 'A46 TT19 Nguyễn Khuyến, Phường Phúc La, Quận Hà Đông, Hà Nội'},
#     {'display_value': 'TTcase',
#      'count': 2749,
#      'logo': 'https://salt.tikicdn.com/ts/seller/a0/0f/b0/8d99f12a36809f9bca618655f0f7bd61.jpg',
#      'query_value': 51508,
#      'seller_address': '207 ngõ trại cá, Phường Trương Định, Quận Hai Bà Trưng, Hà Nội'},
#     {'display_value': 'Laptop Minh Hà',
#      'count': 2512,
#      'logo': 'https://salt.tikicdn.com/ts/seller/2c/4d/98/81092acd0fa710b3c2f6f15bfd2aaa6e.jpg',
#      'query_value': 126154,
#      'seller_address': 'Số 10 ngõ 161 Thái Hà, Phường Trung Liệt, Quận Đống Đa, Hà Nội'},
#     {'display_value': 'HI PC',
#      'count': 2475,
#      'logo': 'https://salt.tikicdn.com/ts/seller/7f/47/88/d2cbb53420e48897eb542e39a2c630e0.jpg',
#      'query_value': 192874,
#      'seller_address': '30B Bà Triệu, Phường Hàng Bài, Quận Hoàn Kiếm, Hà Nội'},
#     {'display_value': 'Shop Linh Kiên Laptop Tin Cậy 100',
#      'count': 2167,
#      'logo': 'https://salt.tikicdn.com/ts/seller/c5/c9/df/7e9bc5709e00dd09aabdfb21c00e318a.jpg',
#      'query_value': 175595,
#      'seller_address': 'Số 22A Ngõ 260 Đường Cầu Giấy, Phường Quan Hoa, Quận Cầu Giấy, Hà Nội'},
#     {'display_value': 'Hoàng Hải Store',
#      'count': 1855,
#      'logo': 'https://salt.tikicdn.com/ts/seller/d1/56/b9/e18d52e743d50fe9fb9f924df5976072.jpg',
#      'query_value': 11205,
#      'seller_address': '449 phố Kim Ngưu, Phường Vĩnh Tuy, Quận Hai Bà Trưng, Hà Nội'},
#     {'display_value': 'Magideal',
#      'count': 1244,
#      'logo': 'https://salt.tikicdn.com/ts/seller/e9/01/24/42ca7d8a587dcab1631eb55080ecee6a.jpg',
#      'query_value': 96293,
#      'seller_address': ''},
#     {'display_value': '3C accessories store',
#      'count': 926,
#      'logo': 'https://salt.tikicdn.com/ts/seller/3c/fd/f8/a0b3c2723996bcae092ba7c7a79bcb7c.jpg',
#      'query_value': 187832,
#      'seller_address': ''},
#     {'display_value': 'feimaoling',
#      'count': 767,
#      'logo': 'https://salt.tikicdn.com/ts/seller/3c/fd/f8/3664005794ea316a934e19d810c51fbd.jpg',
#      'query_value': 219450,
#      'seller_address': ''},
#     {'display_value': 'MacGu Shop',
#      'count': 681,
#      'logo': 'https://salt.tikicdn.com/ts/seller/ff/77/93/8c7791f7482d7e44abb2fcc162c73d80.jpg',
#      'query_value': 203037,
#      'seller_address': 'số 2 ngách 37 ngõ 44 trần thái tông, Phường Dịch Vọng Hậu, Quận Cầu Giấy, Hà Nội'},
#     {'display_value': 'dabaiyu',
#      'count': 572,
#      'logo': 'https://salt.tikicdn.com/ts/seller/3c/fd/f8/ac21ad6f6af778b5c21f2afc66cbcd1c.jpg',
#      'query_value': 219452,
#      'seller_address': ''},
#     {'display_value': 'OceanNet',
#      'count': 537,
#      'logo': 'https://salt.tikicdn.com/ts/seller/72/a8/03/444bd9965de3bd637b206f689bb0fb56.jpg',
#      'query_value': 43349,
#      'seller_address': ''},
#     {'display_value': 'CINZELA Store',
#      'count': 526,
#      'logo': 'https://salt.tikicdn.com/ts/seller/a5/44/55/68d31c11038253160eec31a2ca4f4016.jpg',
#      'query_value': 202816,
#      'seller_address': ''},
#     {'display_value': 'amazingln',
#      'count': 518,
#      'logo': 'https://salt.tikicdn.com/ts/seller/f6/61/0a/1df5c28568064c01d166163313f66eb6.jpg',
#      'query_value': 184562,
#      'seller_address': ''},
#     {'display_value': 'Thế giới balô',
#      'count': 507,
#      'logo': 'https://salt.tikicdn.com/ts/seller/e5/e8/bc/22ab62f175eaf202b477fb8aac42c307.jpg',
#      'query_value': 21766,
#      'seller_address': '6/54 QUANG TRUNG, Thị trấn Hóc Môn, Huyện Hóc Môn, Hồ Chí Minh'},
#     {'display_value': 'BALO MỚI',
#      'count': 479,
#      'logo': 'https://salt.tikicdn.com/ts/seller/b1/e1/fe/428ed2210b63f16a6be977d065737eff.jpg',
#      'query_value': 8109,
#      'seller_address': '489B/24 Hậu Giang, Phường 11, Quận 6, Hồ Chí Minh'},
#     {'display_value': 'MunNiNi',
#      'count': 474,
#      'logo': 'https://salt.tikicdn.com/ts/seller/5a/cc/5a/5f70b57e60704274c45d4dc62766c1ee.jpg',
#      'query_value': 151024,
#      'seller_address': '164/23 Tô Hiệu , Phường Hiệp Tân, Quận Tân Phú, Hồ Chí Minh'},
#     {'display_value': 'THÊ GIƠI BALO 2',
#      'count': 461,
#      'logo': 'https://salt.tikicdn.com/ts/seller/e5/e8/bc/d8d664527d33737611824008ee0d8ab4.jpg',
#      'query_value': 79460,
#      'seller_address': '900 lê Đức thọ,p15, quận gò vấp, Phường 15, Quận Gò Vấp, Hồ Chí Minh, Phường 15, Quận Gò Vấp, Hồ Chí Minh'},
#     {'display_value': 'Balo xinh',
#      'count': 444,
#      'logo': 'https://salt.tikicdn.com/ts/seller/4b/54/1a/f385a79a716cb3505f152e7af8c769aa.png',
#      'query_value': 139911,
#      'seller_address': '900 Lê đức thọ, Phường 15, Quận Gò Vấp, Hồ Chí Minh'},
#     {'display_value': 'HASAN',
#      'count': 440,
#      'logo': 'https://salt.tikicdn.com/ts/seller/15/23/70/b1bb0a6f77ce8898fbb0b53f394c20b9.png',
#      'query_value': 9028,
#      'seller_address': '87/85/1A Thạnh Xuân 22, Phường Thạnh Xuân, Quận 12, Hồ Chí Minh'},
#     {'display_value': 'Benguna',
#      'count': 440,
#      'logo': 'https://salt.tikicdn.com/ts/seller/81/54/0a/2bef51cf360289dea8b8e48ccf993389.jpg',
#      'query_value': 167547,
#      'seller_address': ''},
#     {'display_value': 'TOPGOODVIEW',
#      'count': 428,
#      'logo': 'https://salt.tikicdn.com/ts/seller/3c/fd/f8/d7341638e6f0f62f6e853db3641affc5.jpg',
#      'query_value': 219469,
#      'seller_address': ''},
#     {'display_value': 'azskin',
#      'count': 402,
#      'logo': 'https://salt.tikicdn.com/ts/seller/8e/0d/85/c8823fd599c57e8954cd814b5964706c.jpg',
#      'query_value': 41726,
#      'seller_address': '76 ngõ 259, Phường Đồng Tâm, Quận Hai Bà Trưng, Hà Nội'},
#     {'display_value': 'Joy Wave',
#      'count': 391,
#      'logo': 'https://salt.tikicdn.com/ts/seller/23/ab/ee/507a8be65ffbbd07840ae8830d64c707.jpg',
#      'query_value': 90971,
#      'seller_address': ''},
#     {'display_value': 'linhtranggroup',
#      'count': 387,
#      'logo': 'https://salt.tikicdn.com/ts/seller/4b/54/1a/f385a79a716cb3505f152e7af8c769aa.png',
#      'query_value': 15773,
#      'seller_address': 'Số 5b ngõ 5 Nguyễn Khang, Phường Yên Hoà, Quận Cầu Giấy, Hà Nội'}],
#    'collapsed': 5,
#    'multi_select': True},
#   {'query_name': 'is_cross_border',
#    'display_name': 'Giao Hàng',
#    'values': [{'display_value': 'Hàng nội địa',
#      'count': 16057,
#      'query_value': '0'},
#     {'display_value': 'Hàng quốc tế', 'count': 6951, 'query_value': '1'}],
#    'collapsed': 5,
#    'multi_select': False}],
#  'experiment_variants': {},
#  'model_name': 'model_ltr_features_34_slop_merged_new_labels_xgb_1000',
#  'amplitude': {'number_of_sponsored_product_ad': '13',
#   'number_of_display_ad': '0',
#   'number_of_brand_store_ad': '5',
#   'detected_brand_name': '',
#   'detected_brand_score': '0.0',
#   'detected_primary_category_name': 'Laptop Truyền Thống',
#   'detected_l1_category_name': 'Laptop - Máy Vi Tính - Linh kiện',
#   'category_l1_name': 'Laptop - Máy Vi Tính - Linh kiện',
#   'selected_sort_option': '',
#   'seller_product_sku': '1525769524578,8683178117998,5244909000196,3226775600659,5037884571283,7704951705268,8466124629038,5497778605129,9168518423896,6794012186052,4365506440169,3892425863187,1181475236961,3685838601622,2478773217449,8051802042936,3009176516267,2117388978250,1977455858094,5740382762502,8108320591131,6389285287488,4848751010735,1689139549506,9130432328023,3201079602948,8726239927616,7177087416851,2268481364623,5909362043353,6960582418346,9973668187472,7015163804781,2708474127350,2107829282800,8108320591131,3892425863187,4869523489732,8755383485280,2113442336762,1594038767055,2683576616357,7072981914624,7816547019605,8532109252344,1969355727438,1650622910066,3536185017163,3340505079463,2062227500204,5857132354372,2486231413563,4285116155354,5339538889617,2853883437906,7092750263137,8219864644115,3823475096007,5421126277820,1719040023029,6339039960296'},
#  'trace_id': 'tXzoxTWQ'}

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['data', 'paging', 'widgets', 'sort_options', 'filters', 'experiment_variants', 'model_name', 'amplitude', 'trace_id'])

# %%
list = data["data"]

# %%
len(list)
# Out:
# 61

# %%
list[0]
# Out:
# {'id': 72750441,
#  'sku': '1525769524578',
#  'name': 'Bàn Phím Cơ mini không dây Bluetooth 5.0 Ajazz AK33 White Chống ồn - hàng nhập khẩu',
#  'url_key': 'ban-phim-co-mini-khong-day-bluetooth-5-0-ajazz-ak33-whitechong-on-hang-nhap-khau-p72750441',
#  'url_path': 'ban-phim-co-mini-khong-day-bluetooth-5-0-ajazz-ak33-whitechong-on-hang-nhap-khau-p72750441.html?spid=72750444',
#  'type': 'simple',
#  'brand_name': 'Ajazz',
#  'short_description': '- Bàn Phím Cơ mini không dây Bluetooth 5.0 Ajazz AK33 Chống ồn Gọn gàng , đơn giản và tinh tế- Switch 82 Phím Chống ồn- Led trắng đơn sắc đơn giản sang trọng không màu mè- Chất liệu kim loại- Kết nối...',
#  'price': 930000,
#  'list_price': 930000,
#  'original_price': 930000,
#  'badges_new': [{'placement': 'bottom',
#    'type': 'icon_badge',
#    'code': 'freeship_tikifast',
#    'icon': 'https://salt.tikicdn.com/ts/upload/dc/0d/49/3251737db2de83b74eba8a9ad6d03338.png',
#    'icon_width': 136,
#    'icon_height': 24},
#   {'placement': 'under_price',
#    'type': 'under_price_icon',
#    'code': 'is_best_price_guaranteed',
#    'icon': 'https://salt.tikicdn.com/ts/upload/51/ac/cc/528e80fe3f464f910174e2fdf8887b6f.png',
#    'icon_width': 124,
#    'icon_height': 18,
#    'text': ''},
#   {'placement': 'bottom_right',
#    'type': 'icon_badge',
#    'code': 'video_icon',
#    'icon': 'https://salt.tikicdn.com/ts/upload/d5/f3/6f/fdd40db52ff4afe497d0c2240dcfd25b.png',
#    'icon_width': 28,
#    'icon_height': 28},
#   {'placement': 'top',
#    'type': 'icon_badge',
#    'code': 'trusted_store',
#    'icon': 'https://salt.tikicdn.com/ts/upload/e0/41/da/bb0fc684a838eff5e264ce0534a148f0.png',
#    'icon_width': 58,
#    'icon_height': 18}],
#  'discount': 0,
#  'discount_rate': 0,
#  'rating_average': 5,
#  'review_count': 2,
#  'order_count': 0,
#  'favourite_count': 0,
#  'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product
#     'properties': {'product_id': '72750444'},
#     'type': 'ProductAdvertType',
#     'seller_id': 58789}]}}

# %%
idsp = []
sku = []
name = []
brand_name = []
price = []
short_description = []
for item in range(len(list)):
    idsp.append(list[item]["id"])
    sku.append(list[item]["sku"])
    name.append(list[item]["name"])
    brand_name.append(list[item]["brand_name"])
    price.append(list[item]["price"])
    short_description.append(list[item]["short_description"])

# %%
df = pd.DataFrame({"idsp":idsp,"sku":sku,"name":name,"brand_name":brand_name,"price":price,"short_description":short_description})

# %%
df
# Out:
#          idsp            sku  \
# 0    72750441  1525769524578
# 1   124742926  8683178117998
# 2   125013938  5244909000196
# 3   143022287  3226775600659
# 4   116629798  5037884571283
# 5   108591561  7704951705268
# 6   135093811  8466124629038
# 7   142795843  5497778605129
# 8   120782190  9168518423896
# 9   129937277  6794012186052
# 10  127380504  4365506440169
# 11  136959272  3892425863187
# 12  137014231  1181475236961
# 13  135268246  3685838601622
# 14   97045023  2478773217449
# 15   37889069  8051802042936
# 16   20549945  3009176516267
# 17   95996882  2117388978250
# 18  141740640  1977455858094
# 19  118528503  5740382762502
# 20  113577973  8108320591131
# 21   81503768  6389285287488
# 22  129602068  4848751010735
# 23  136045731  1689139549506
# 24  136975224  9130432328023
# 25   81508726  3201079602948
# 26  108336898  8726239927616
# 27  118526595  7177087416851
# 28  115708103  2268481364623
# 29  135727678  5909362043353
# ..        ...            ...
# 31   75557641  9973668187472
# 32  124785827  7015163804781
# 33  140758658  2708474127350
# 34  142795841  2107829282800
# 35  113577973  8108320591131
# 36  136959272  3892425863187
# 37   49206793  4869523489732
# 38  124903733  8755383485280
# 39   21045531  2113442336762
# 40  135777002  1594038767055
# 41  134018636  2683576616357
# 42   73795655  7072981914624
# 43   97034085  7816547019605
# 44  139815379  8532109252344
# 45  141322626  1969355727438
# 46  118526695  1650622910066
# 47   97007193  3536185017163
# 48  114243462  3340505079463
# 49   47374311  2062227500204
# 50  143338713  5857132354372
# 51  121405793  2486231413563
# 52  133697603  4285116155354
# 53  108924121  5339538889617
# 54  126507499  2853883437906
# 55  117078846  7092750263137
# 56   87004942  8219864644115
# 57  143061390  3823475096007
# 58  135112051  5421126277820
# 59  143338711  1719040023029
# 60  138919075  6339039960296
#
#                                                  name brand_name     price  \
# 0   Bàn Phím Cơ mini không dây Bluetooth 5.0 Ajazz...      Ajazz    930000
# 1   Apple MacBook Air M1 2020 - 13 Inchs (8GB / 16...      Apple  30590000
# 2   Apple MacBook Pro M1 2020 - 13 Inchs (8GB / 16...      Apple  35990000
# 3   Laptop Asus ZenBook Flip S UX371EA-HL725WS (Co...       Asus  39759000
# 4   Đế tản nhiệt laptop máy tính 3, 6 quạt có đèn ...        OEM    249000
# 5   Laptop HP 340s G7 224L1PA i3 1005G1 | 4GB RAM ...         HP  13890000
# 6   Laptop Dell Inspiron 15 3511 P112F001ABL (Đen)...       Dell  15190000
# 42  Apple MacBook Pro 2020 M1 - 13 Inchs (Apple M1...      Apple  31890000
# 43  Laptop HP ProBook 430 G8 2H0N7PA (Core i5-1135...         HP  19209000
# 44  Laptop MSI Modern 14 B11MOU-460VN (i7-1165G7, ...        MSI  21990000
# 45  Laptop Lenovo IdeaPad 3 15ITL6 82H80042VN (Cor...     Lenovo  18490000
# 46  Laptop Dell Vostro 3405 V4R53500U003W(AMD R5-3...       Dell  16890000
# 47  Laptop HP ProBook 430 G8 2H0N9PA (Core i5-1135...         HP  21590000
# 48  Giá Đỡ Máy Tính, Laptop, iPad, Macbook Hợp Kim...   Tamayoko    499000
# 49  Surface Pro 7 Core I3 Ram 4Gb Sdd 128Gb Brand ...    Surface  18189000
# 50  Laptop Asus ExpertBook L1400CDA-EK0490T (AMD R...       Asus  13389000
# 51  Laptop Acer Aspire A514 54 53T8 i5 1135G7/8GB/...       Acer  19990000
# 52  Laptop Dell Vostro 3405 (V4R53500U003W) (R5 35...       Dell  16890000
# 53  Laptop Dell Latitude 3520 - 70251603 Đen (Cpu ...       Dell  14990000
# 54  Laptop Lenovo IdeaPad 3 14ITL6 i3-1115G4 14 in...     Lenovo  14490000
# 55  Laptop Dell Vostro 5402 (V4I5003W) (i5 1135G7 ...       Dell  20490000
# 56  Laptop HP 340s G7 i7-1065G7/8GD4/256GSSD/14.0F...         HP  20990000
# 57  Laptop Acer Gaming Aspire 7 A715-42G-R1SB- Hàn...       Acer  20990000
# 58  Laptop Dell Vostro 3400 Core i5-1135G7 / RAM 8...       Dell  21450000
# 59  Laptop Asus ExpertBook B1400CEAE-EK3724 (Core ...       Asus  19259000
# 60  Laptop Lenovo Ideapad Slim 3 14IIL05 81WD005KV...     Lenovo  13490000
#
#                                     short_description
# 0   - Bàn Phím Cơ mini không dây Bluetooth 5.0 Aja...
# 1   \nNội dung tính năng\nMacBook Air là máy tính ...
# 2   \n\n\nNội dung tính năng\nMacbook Pro 13 inch ...
# 3   Thiết kế đẹp mắt, hiện đại\nLaptop Asus ZenBoo...
# 4   Đế tản nhiệt laptop máy tính có đèn LED cực đẹ...
# 5   \n \n \n  \n   Thông số kỹ thuật:\n   RAM: 4GB...
# 6   Laptop Dell Inspiron 15 3511 P112F001ABL với t...
# 7   \nHiệu năng mạnh mẽ, card đồ hoạ chất lượng\nL...
# 8   Giá đỡ / Đế đỡ tản nhiệt dành cho laptop, macb...
# 9   Thiết kế &amp; ngoại hình\nLaptop Dell Vostro ...
# 10  Gọn gàng, tinh tế trên từng đường nét máyĐược ...
# 11  Dell XPS 13 9310 2in1 70262931 được thiết kế n...
# 12  \nCPU: Intel Core i5-1135G7 (upto 4.20GHz, 8MB...
# 13  Thiết kế nhỏ gọn, thanh lịch\nLaptop HP Envy 1...
# 14  Thiết kế nhỏ gọn bắt mắt\nLaptop Acer Aspire 3...
# 15  Thiết kế cao cấp, sang trọng\nApple Macbook Pr...
# 16  ĐẶC ĐIỂM NỔI BẬT\nQuạt kích thước lớn, bề mặt ...
# 17  Operating System Chrome OS11.6" inch 1366 x 76...
# 18  Kiểu dáng thanh lịch, sang trọng \nMSI Modern ...
# 19  \n\nLaptop Dell Vostro 3400 V4I7015W (i7 1165G...
# 20  Thiết kế sang trọng\nLaptop Dell Latitude 3420...
# 21  Thiết kế mạnh mẽ\nLaptop Dell Vostro 3500 V350...
# 22  \nLaptop Dell Inspiron 15 3505 Y1N1T3\nThông s...
# 23  Laptop HP Envy 13 ba1030TU i7 (2K0B6PA) sở hữu...
# 24  \nCPU: AMD Ryzen 7 5800U (1.9GHz up to 4.4GHz,...
# 25  Mạnh, bền bỉ, trẻ trung đa sắc màu\nLaptop Ace...
# 26  Vẻ ngoài công sở đầy tinh tế\nLaptop HP 1...
# 27  \n\nLaptop Dell Vostro 14 3405 (3405-V4R53500U...
# 28  \n\nChất liệu hợp kim nhôm cao cấp sản phậm nh...
# 29  Mang đến kiểu dáng sang trọng và đẳng cấp, lap...
# ..                                                ...
# 31  Cảm nhận sức mạnh\nBộ xử lý Intel Core I7 Thế ...
# 32  DELL INSPIRON T5410\n- Ra đời vào nửa đầu năm ...
# 33  Sở hữu thiết kế mỏng nhẹ và thanh lịch\nLaptop...
# 34  \nThiết kế bắt mắt, có nhiều thay đổi tích cực...
# 35  Thiết kế sang trọng\nLaptop Dell Latitude 3420...
# 36  Dell XPS 13 9310 2in1 70262931 được thiết kế n...
# 37  \nMicrosoft Surface Laptop 3 – Sự nâng cấp mới...
# 38  \nNội dung tính năng\nMac mini với chip Apple ...
# 39  THÔNG SỐ KỸ THUẬT\n\n\n\n\n\nBộ vi xử lý (CPU)...
# 40  - Bộ Bàn phím Chuột không dây mini WL619 - pin...
# 41  ASUS ExpertBook B1400 được thiết kế dành cho d...
# 42  Thiết kế trau chuốt từng đường nét, trải nghiệ...
# 43  Thiết kế hiện đại cho phong cách làm việc hiện...
# 44  Hoàn thành xuất sắc mọi công việc với hiệu suấ...
# 45  Laptop Lenovo IdeaPad 3 15ITL6 82H80042VN INTE...
# 46  \n\nLaptop Dell Vostro 14 3405 (3405-V4R53500U...
# 47  Thiết kế linh hoạt, cứng cáp\nLaptop HP ProBoo...
# 48                               \n\n\n\n\n\n\n\n\n\n
# 49  Màn hình12.3 inch PixelSense, 2736×1824 (267 p...
# 50  Thiết kế mỏng và nhẹ\nLaptop Asus ExpertBook L...
# 51  Acer Aspire A514 54 53T8 i5 (NX.A2ASV.006) man...
# 52  Đánh giá Laptop Dell Vostro 3405 (V4R53500U003...
# 53  CPU: Intel Core i3-1115G4 (upto 4.10GHz, 6MB)R...
# 54  \nTrải nghiệm hình ảnh sắc nét trên màn hình F...
# 55  Laptop Dell Vostro 5402 (V4I5003W) (i5 1135G7 ...
# 56  Model: 36A36PA_DCPU: Intel Core i7-1065G7RAM/S...
# 57  \nCPU AMD Ryzen R5-5500U (8MB, up to 4.00GHz)\...
# 58  DELL VOSTRO 3400 - HÀNG BRAND NEW, NGUYÊN TEM ...
# 59  Hiệu năng toàn diện đỉnh cao\nHãy tận hưởng hi...
# 60  Hệ điều hành : Windows 10 Home SL\nBộ vi xử lý...
#
# [61 rows x 6 columns]

# %%
df.to_csv('out.csv',index = False)
